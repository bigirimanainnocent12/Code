# %% [markdown]
# <a href="https://colab.research.google.com/github/bigirimanainnocent12/Code/blob/main/Fin_FERMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Charger le fichier Excel
df = pd.read_excel('Classeur1.xlsx', engine='openpyxl')

# %%
df
# Out:
#              id   Temps  Csg_T     CO2      V  \
# 0       5233639    0.00   20.0   0.000  0.000
# 1       5233640    0.33   20.0  -0.040  0.000
# 2       5233641    0.67   20.0   0.080 -0.360
# 3       5233642    1.00   20.0   0.020  0.099
# 4       5233643    1.33   20.0  -0.060  0.205
# ...         ...     ...    ...     ...    ...
# 417280  5320371  503.67   15.0  94.161  0.078
# 417281  5320372  504.00   15.0  94.161  0.077
# 417282  5320373  504.33   15.0  94.221  0.076
# 417283  5320374  504.67   15.0  94.242  0.083
# 417284  5320375  505.00   15.0  94.242  0.082
#
#                                                      Code           Souche  \
# 0       F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  D254 35g 2m 20C
# 1       F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  D254 35g 2m 20C
# 2       F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  D254 35g 2m 20C
# 3       F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  D254 35g 2m 20C
# 4       F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  D254 35g 2m 20C
# ...                                                   ...              ...
# 417280  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...    4754063G stab
# 417281  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...    4754063G stab
# 417282  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...    4754063G stab
# 417283  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...    4754063G stab
# 417284  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...    4754063G stab
#
#                  Milieu volume
# 0             Sauvi mix  Salle
# 1             Sauvi mix  Salle
# 2             Sauvi mix  Salle
# 3             Sauvi mix  Salle
# 4             Sauvi mix  Salle
# ...                 ...    ...
# 417280  MS N460 S230-FA  Salle
# 417281  MS N460 S230-FA  Salle
# 417282  MS N460 S230-FA  Salle
# 417283  MS N460 S230-FA  Salle
# 417284  MS N460 S230-FA  Salle
#
# [417285 rows x 9 columns]

# %%
resultats=[]
for code in df['Code'].unique():
    data = df[df["Code"] == code]

    filtered_df = data[(data['CO2'] >= 3) & (data['CO2'] <= 40)]

    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df.index = range(0, len(filtered_df))

    result = filtered_df['V'].max()
    tempsmax=filtered_df.iloc[filtered_df['V'].idxmax()]['Temps']


    filtered_data_temps = data[data['Temps'] >= 50]


    max_co2 = filtered_data_temps['CO2'].max()


    tempsmaxco2= filtered_data_temps.loc[filtered_data_temps['CO2'].idxmax(), 'Temps']


    result_dict = {
    'Code':code,
    'Max_V':result,
    'Tempsmax':tempsmax,
    'max_co2':max_co2,
    'tempsmaxco2':tempsmaxco2
  }
    resultats.append(result_dict)


DF = pd.DataFrame(resultats)

# %%
DF['Maxco2_85']=DF['max_co2']*0.85
DF['Maxco2_98']=DF['max_co2']*0.98
DF['Maxco2_70']=DF['max_co2']*0.7
DF['Maxco2_80']=DF['max_co2']*0.8
DF
# Out:
#                                                   Code  Max_V  Tempsmax  \
# 0    F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  1.100     41.67
# 1          D14_2021-06-04 13:54:00_268 0553V_Sauvi mix  0.910     38.22
# 2          D13_2021-06-04 13:54:00_268 0543V_Sauvi mix  0.930     40.24
# 3          D15_2021-06-04 13:54:00_268 1340V_Sauvi mix  0.730     59.35
# 4       F8_2021-11-04 11:53:00_OK 25g 2m 20C_Sauvi mix  1.147     58.33
# ..                                                 ...    ...       ...
# 611  F20_2021-02-16 14:50:00_482 218300_MS N460 S23...  1.125     50.00
# 612  F15_2021-02-16 14:49:00_475 4073G T0_MS N460 S...  0.434     74.33
# 613  F17_2021-02-16 14:49:00_4754073G stab_MS N460 ...  0.440     67.33
# 614  F14_2021-02-24 14:39:00_4754063G stab_MS N460 ...  0.569     70.33
# 615  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...  0.456     69.00
#
#      max_co2  tempsmaxco2  Maxco2_90  Maxco2_95  Maxco2_70  Maxco2_80  \
# 0    121.311       595.67  103.11435  118.88478    84.9177    97.0488
# 1    109.600       403.38   93.16000  107.40800    76.7200    87.6800
# 2    107.180       402.60   91.10300  105.03640    75.0260    85.7440
# 3    108.740       403.37   92.42900  106.56520    76.1180    86.9920
# 4    102.939       283.00   87.49815  100.88022    72.0573    82.3512
# ..       ...          ...        ...        ...        ...        ...
# 611  113.834       645.33   96.75890  111.55732    79.6838    91.0672
# 612  112.388      1077.00   95.52980  110.14024    78.6716    89.9104
# 613  111.324      1157.00   94.62540  109.09752    77.9268    89.0592
# 614  113.978       867.00   96.88130  111.69844    79.7846    91.1824
# 615   94.242       504.67   80.10570   92.35716    65.9694    75.3936
#
#      Maxco2_98  Maxco2_85
# 0    118.88478  103.11435
# 1    107.40800   93.16000
# 2    105.03640   91.10300
# 3    106.56520   92.42900
# 4    100.88022   87.49815
# ..         ...        ...
# 611  111.55732   96.75890
# 612  110.14024   95.52980
# 613  109.09752   94.62540
# 614  111.69844   96.88130
# 615   92.35716   80.10570
#
# [616 rows x 11 columns]

# %%
import statsmodels.formula.api as sm
resul=[]
for code in df['Code'].unique():
  data = df[df["Code"] == code]
  # Get the values as a single value instead of a Series
  maxco2_90_value = DF[DF["Code"] == code]["Maxco2_85"].iloc[0]
  maxco2_95_value = DF[DF["Code"] == code]["Maxco2_98"].iloc[0]
  #Now we compare using the single values instead of Series
  datafil=data[(data['CO2'] >= maxco2_90_value) & (data['CO2'] <= maxco2_95_value)]
  modele=sm.ols('V ~ Temps',data=datafil).fit()
  A0=modele.params.Intercept
  A1=modele.params.Temps

  result = {
    'code':code,
    'A0':float(A0),
    'A1':float(A1),
  }
  resul.append(result)
DF2 = pd.DataFrame(resul)
DF2
# Out:
#                                                   code        A0        A1
# 0    F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  0.229848 -0.000387
# 1          D14_2021-06-04 13:54:00_268 0553V_Sauvi mix  0.778847 -0.002260
# 2          D13_2021-06-04 13:54:00_268 0543V_Sauvi mix  0.746722 -0.002104
# 3          D15_2021-06-04 13:54:00_268 1340V_Sauvi mix  0.500118 -0.001029
# 4       F8_2021-11-04 11:53:00_OK 25g 2m 20C_Sauvi mix  0.449935 -0.001150
# ..                                                 ...       ...       ...
# 611  F20_2021-02-16 14:50:00_482 218300_MS N460 S23...  0.294919 -0.000445
# 612  F15_2021-02-16 14:49:00_475 4073G T0_MS N460 S...  0.161968 -0.000157
# 613  F17_2021-02-16 14:49:00_4754073G stab_MS N460 ...  0.130954 -0.000114
# 614  F14_2021-02-24 14:39:00_4754063G stab_MS N460 ...  0.240261 -0.000303
# 615  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...  0.200213 -0.000237
#
# [616 rows x 3 columns]

# %%
DF2['FIN_FERMENTATION']=-DF2['A0']/DF2['A1']
DF2
# Out:
#                                                   code        A0        A1  \
# 0    F11_2021-11-04 11:54:00_D254 35g 2m 20C_Sauvi mix  0.229848 -0.000387
# 1          D14_2021-06-04 13:54:00_268 0553V_Sauvi mix  0.778847 -0.002260
# 2          D13_2021-06-04 13:54:00_268 0543V_Sauvi mix  0.746722 -0.002104
# 3          D15_2021-06-04 13:54:00_268 1340V_Sauvi mix  0.500118 -0.001029
# 4       F8_2021-11-04 11:53:00_OK 25g 2m 20C_Sauvi mix  0.449935 -0.001150
# ..                                                 ...       ...       ...
# 611  F20_2021-02-16 14:50:00_482 218300_MS N460 S23...  0.294919 -0.000445
# 612  F15_2021-02-16 14:49:00_475 4073G T0_MS N460 S...  0.161968 -0.000157
# 613  F17_2021-02-16 14:49:00_4754073G stab_MS N460 ...  0.130954 -0.000114
# 614  F14_2021-02-24 14:39:00_4754063G stab_MS N460 ...  0.240261 -0.000303
# 615  F16_2021-02-16 14:49:00_4754063G stab_MS N460 ...  0.200213 -0.000237
#
#      FIN_FERMENTATION
# 0          593.480593
# 1          344.666165
# 2          354.885116
# 3          486.170416
# 4          391.259814
# ..                ...
# 611        663.263003
# 612       1034.023765
# 613       1146.057436
# 614        793.298951
# 615        843.451705
#
# [616 rows x 4 columns]
